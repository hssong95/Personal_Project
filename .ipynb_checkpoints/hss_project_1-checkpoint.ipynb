# %% [markdown]
# # 1. Import Data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn
import math

# %%
data_origin = pd.read_csv("vgames2.csv")

# %%
data_origin.head()
# Out:
#    Unnamed: 0                                            Name Platform  \
# 0           1                    Candace Kane's Candy Factory       DS
# 1           2                                  The Munchables      Wii
# 2           3  Otome wa Oanesama Boku ni Koi Shiteru Portable      PSP
# 3           4                Deal or No Deal: Special Edition       DS
# 4           5       Ben 10 Ultimate Alien: Cosmic Destruction      PS3
#
#      Year      Genre           Publisher NA_Sales EU_Sales JP_Sales  \
# 0  2008.0     Action           Destineer     0.04        0        0
# 1  2009.0     Action  Namco Bandai Games     0.17        0        0
# 2  2010.0  Adventure           Alchemist        0        0     0.02
# 3  2010.0       Misc           Zoo Games     0.04        0        0
# 4  2010.0   Platform         D3Publisher     0.12     0.09        0
#
#   Other_Sales
# 0           0
# 1        0.01
# 2           0
# 3           0
# 4        0.04

# %%
data_origin.columns
# Out:
# Index(['Unnamed: 0', 'Name', 'Platform', 'Year', 'Genre', 'Publisher',
#        'NA_Sales', 'EU_Sales', 'JP_Sales', 'Other_Sales'],
#       dtype='object')

# %% [markdown]
# ---
#
# # 2. Preprocessing

# %% [markdown]
# > ## 2.1 Delete null & duplicates

# %%
data_origin=data_origin.drop(columns=['Unnamed: 0'])

# %%
data_origin.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16598 entries, 0 to 16597
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Name         16598 non-null  object
#  1   Platform     16598 non-null  object
#  2   Year         16327 non-null  float64
#  3   Genre        16548 non-null  object
#  4   Publisher    16540 non-null  object
#  5   NA_Sales     16598 non-null  object
#  6   EU_Sales     16598 non-null  object
#  7   JP_Sales     16598 non-null  object
#  8   Other_Sales  16598 non-null  object
# dtypes: float64(1), object(8)
# memory usage: 1.1+ MB

# %%
data_origin.isnull().sum()
# Out:
# Name             0
# Platform         0
# Year           271
# Genre           50
# Publisher       58
# NA_Sales         0
# EU_Sales         0
# JP_Sales         0
# Other_Sales      0
# dtype: int64

# %%
data_origin[data_origin.Year.isnull()].sample(10)
# Out:
#                                          Name Platform  Year         Genre  \
# 1301                             Move Fitness      PS3   NaN        Sports
# 11641  AKB1/48: Idol to Guam de Koishitara...     X360   NaN          Misc
# 4196                   Test Drive Unlimited 2     X360   NaN        Racing
# 3238                    Football Manager 2007     X360   NaN        Sports
# 1011                   Tribes: Aerial Assault      PS2   NaN       Shooter
# 15147    Nicktoons: Battle for Volcano Island       GC   NaN        Action
# 5140                               BioShock 2       PC   NaN       Shooter
# 3187                              Jet Impulse       DS   NaN    Simulation
# 9016          Disgaea 3: Absence of Detention      PSV   NaN  Role-Playing
# 7713                         Our House Party!      Wii   NaN    Simulation
#
#                          Publisher NA_Sales EU_Sales JP_Sales Other_Sales
# 1301   Sony Computer Entertainment        0     0.17        0        0.05
# 11641                          NaN        0        0     0.01           0
# 4196                         Atari      0.3     0.32        0        0.07
# 3238                          Sega        0     0.01        0           0
# 1011                       Unknown     0.11     0.09        0        0.03
# 15147                      Unknown     0.22     0.06        0        0.01
# 5140          Take-Two Interactive     0.02     0.19        0        0.04
# 3187                      Nintendo        0        0     0.02           0
# 9016          Nippon Ichi Software     0.13     0.06     0.07        0.04
# 7713                       Unknown     0.13        0        0        0.01

# %%
data_origin[data_origin.Publisher.isnull()]
# Out:
#                                                     Name Platform    Year  \
# 272                                   UK Truck Simulator       PC  2010.0
# 1313      All Grown Up!: Game Boy Advance Video Volume 1      GBA  2004.0
# 14383                   Thomas the Tank Engine & Friends      GBA  2004.0
# 14474                             Driving Simulator 2011       PC  2011.0
# 14828  Codename: Kids Next Door: Game Boy Advance Vid...      GBA  2004.0
# 15151  SpongeBob SquarePants: Game Boy Advance Video ...      GBA  2004.0
# 15368       Shrek / Shrek 2 2-in-1 Gameboy Advance Video      GBA  2007.0
# 15669                     Yu Yu Hakusho: Dark Tournament      PS2     NaN
# 15805                                       Dream Dancer       DS     NaN
# 16067                                     Bound By Flame     X360  2014.0
# 16130  Super Robot Wars OG Saga: Masou Kishin II - Re...      PSP     NaN
#
#               Genre Publisher NA_Sales EU_Sales JP_Sales Other_Sales
# 272      Simulation       NaN        0     0.03        0           0
# 1313           Misc       NaN     0.17     0.06        0           0
# 1560           Misc       NaN     0.12     0.04        0           0
# 1789           Misc       NaN     0.16     0.06        0           0
# 1879   Role-Playing       NaN        0        0     0.05           0
# 1961           Misc       NaN     0.46     0.17        0        0.01
# 2070        Shooter       NaN        0     0.03        0           0
# 2970     Simulation       NaN        0        0     0.06           0
# 3184         Action       NaN     0.05     0.03        0        0.01
# 3412         Action       NaN        0        0     0.01           0
# 3533      Adventure       NaN        0        0     0.04           0
# 3562       Fighting       NaN     1.57     1.02        0        0.41
# 3639       Strategy       NaN        0     0.01        0           0
# 3684           Misc       NaN     0.12     0.05        0           0
# 4308      Adventure       NaN        0        0     0.02           0
# 4367           Misc       NaN     0.11     0.04        0           0
# 5207           Misc       NaN     0.23     0.08        0        0.01
# 5245           Misc       NaN     0.11     0.04        0           0
# 5387      Adventure       NaN        0        0     0.02           0
# 6209         Sports       NaN        0        0      0.1           0
# 6392        Shooter       NaN     0.01        0        0           0
# 7370       Strategy       NaN     0.06      0.1        0           0
# 7984           Misc       NaN     0.08     0.03        0           0
# 8038           Misc       NaN     0.01        0        0           0
# 8236           Misc       NaN     0.67     0.25        0        0.02
# 8355           Misc       NaN     0.06     0.02        0           0
# 8651       Platform       NaN        0     0.48        0           0
# 8873         Puzzle       NaN        0     0.01        0           0
# 9128           Misc       NaN     0.31     0.11        0        0.01
# 9684         Action       NaN     0.15     0.05     0.14        0.01
# 9877         Sports       NaN        0        0     0.02           0
# 10156        Action       NaN        0        0     0.27        0.01
# 10223    Simulation       NaN        0     0.02        0           0
# 11309        Sports       NaN     0.81     0.55        0         0.1
# 11498          Misc       NaN     0.01     0.01        0           0
# 11641          Misc       NaN        0        0     0.01           0
# 11676    Simulation       NaN        0     0.13        0           0
# 12126        Action       NaN     0.03        0        0           0
# 12176          Misc       NaN     0.18     0.07        0           0
# 12468          Misc       NaN      0.3     0.11        0        0.01
# 12560          Misc       NaN     0.15     0.05        0           0
# 12900          Misc       NaN     0.46     0.17        0        0.01
# 13182          Misc       NaN     0.19     0.07        0           0
# 13204      Platform       NaN        0     0.02        0           0
# 13450          Misc       NaN        0        0     0.03           0
# 13766        Action       NaN        0        0     0.04           0
# 13810          Misc       NaN     0.11     0.04        0           0
# 13837          Misc       NaN     0.18     0.07        0           0
# 13923        Action       NaN     0.06        0        0           0
# 14383     Adventure       NaN     0.13     0.05        0           0
# 14474        Racing       NaN       0M     0.01        0           0
# 14828          Misc       NaN     0.12     0.05        0           0
# 15151          Misc       NaN     0.38     0.14        0        0.01
# 15368          Misc       NaN     0.87     0.32        0        0.02
# 15669      Fighting       NaN      0.1     0.08        0        0.03
# 15805          Misc       NaN     0.01        0        0           0
# 16067  Role-Playing       NaN        0     0.01        0           0
# 16130      Strategy       NaN        0        0     0.12           0

# %%
data = data_origin.drop_duplicates()

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data = data.reset_index(drop=True)

# %%
data.Publisher=data.Publisher.fillna('Unknown')

# %%
data=data.dropna(subset=['Genre'])

# %%
data.isnull().sum()
# Out:
# Name             0
# Platform         0
# Year           270
# Genre            0
# Publisher        0
# NA_Sales         0
# EU_Sales         0
# JP_Sales         0
# Other_Sales      0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16547 entries, 0 to 16596
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Name         16547 non-null  object
#  1   Platform     16547 non-null  object
#  2   Year         16277 non-null  float64
#  3   Genre        16547 non-null  object
#  4   Publisher    16547 non-null  object
#  5   NA_Sales     16547 non-null  object
#  6   EU_Sales     16547 non-null  object
#  7   JP_Sales     16547 non-null  object
#  8   Other_Sales  16547 non-null  object
# dtypes: float64(1), object(8)
# memory usage: 1.3+ MB

# %% [markdown]
# > ## 2.2 Change Sales Value

# %%
data[data.NA_Sales.str.contains(r'[^0-9\.]')]
# Out:
#                                    Name Platform    Year     Genre  \
# 10                          Ford Racing       PS  2001.0    Racing
# 45         Resident Evil: Revelations 2      PS3  2015.0    Action
# 145                  TOCA Race Driver 3       PC  2006.0    Racing
# 447          Medal of Honor: Warfighter     X360  2012.0    Action
# 458                             F1 2010      PS3  2010.0    Racing
# ...                                 ...      ...     ...       ...
# 16329           Midway Arcade Treasures      PS2  2003.0      Misc
# 16407     NASCAR 06: Total Team Control      PS2  2005.0    Racing
# 16481  Super Robot Taisen F Kanketsuhen      SAT    98.0  Strategy
# 16491                     Mortal Kombat      PSV  2012.0  Fighting
# 16577              Gex: Enter the Gecko       PS  1998.0  Platform
#
#                                     Publisher NA_Sales EU_Sales JP_Sales  \
# 10                         Empire Interactive     480K    0.33M       0K
# 45                                     Capcom      60K     0.08     0.16
# 145                               Codemasters       0K     0.02        0
# 447                           Electronic Arts    0.58M     0.47     0.01
# 458                               Codemasters    0.25M     0.76     0.08
# ...                                       ...      ...      ...      ...
# 16329                            Midway Games     720K     0.56        0
# 16407                         Electronic Arts    0.53M     0.02        0
# 16481                               Banpresto       0M        0     0.55
# 16491  Warner Bros. Interactive Entertainment     470K     0.18        0
# 16577           BMG Interactive Entertainment     320K     0.22        0
#
#       Other_Sales
# 10           0.06
# 45           0.03
# 145             0
# 447           0.1
# 458          0.27
# ...           ...
# 16329        0.19
# 16407        0.09
# 16481           0
# 16491        0.12
# 16577        0.04
#
# [199 rows x 9 columns]

# %%
data.NA_Sales=data.NA_Sales.str.replace('M','')
data.EU_Sales=data.EU_Sales.str.replace('M','')
data.JP_Sales=data.JP_Sales.str.replace('M','')
data.Other_Sales=data.Other_Sales.str.replace('M','')

# %%
data[data.NA_Sales.str.contains(r'[^0-9\.]')]
# Out:
#                                                  Name Platform    Year  \
# 10                                        Ford Racing       PS  2001.0
# 45                       Resident Evil: Revelations 2      PS3  2015.0
# 145                                TOCA Race Driver 3       PC  2006.0
# 878    Tears to Tiara Anecdotes: The Secret of Avalon      PS3  2009.0
# 1086                        Pro Evolution Soccer 2014      3DS  2013.0
# ...                                               ...      ...     ...
# 15646                       Championship Manager 2010       PC  2009.0
# 16193                            Vin Diesel: Wheelman      PS3  2009.0
# 16329                         Midway Arcade Treasures      PS2  2003.0
# 16491                                   Mortal Kombat      PSV  2012.0
# 16577                            Gex: Enter the Gecko       PS  1998.0
#
#           Genre                               Publisher NA_Sales EU_Sales  \
# 10       Racing                      Empire Interactive     480K     0.33
# 45       Action                                  Capcom      60K     0.08
# 145      Racing                             Codemasters       0K     0.02
# 878    Strategy                               Aqua Plus       0K        0
# 1086     Action            Konami Digital Entertainment       0K        0
# ...         ...                                     ...      ...      ...
# 15646    Sports                       Eidos Interactive       0K     0.01
# 16193    Racing                                 Ubisoft     120K     0.15
# 16329      Misc                            Midway Games     720K     0.56
# 16491  Fighting  Warner Bros. Interactive Entertainment     470K     0.18
# 16577  Platform           BMG Interactive Entertainment     320K     0.22
#
#       JP_Sales Other_Sales
# 10          0K        0.06
# 45        0.16        0.03
# 145          0           0
# 878       0.04           0
# 1086      0.19           0
# ...        ...         ...
# 15646        0           0
# 16193        0        0.06
# 16329        0        0.19
# 16491        0        0.12
# 16577        0        0.04
#
# [99 rows x 9 columns]

# %%
df1=data[data.NA_Sales.str.contains(r'[^0-9\.]')]
df1.NA_Sales=df1.NA_Sales.str.replace('K','',regex=True).astype(int)
data=data.drop(index=df1.index)
data.NA_Sales=data.NA_Sales.astype(float)*1000
data.NA_Sales=data.NA_Sales.astype(int)
data=pd.concat([data,df1])
data
# Out:
# /var/folders/vd/vty5rfw96l98pjmcyhqfys2h0000gn/T/ipykernel_17442/482337903.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.NA_Sales=df1.NA_Sales.str.replace('K','',regex=True).astype(int)
#                                                  Name Platform    Year  \
# 0                        Candace Kane's Candy Factory       DS  2008.0
# 1                                      The Munchables      Wii  2009.0
# 2      Otome wa Oanesama Boku ni Koi Shiteru Portable      PSP  2010.0
# 3                    Deal or No Deal: Special Edition       DS  2010.0
# 4           Ben 10 Ultimate Alien: Cosmic Destruction      PS3  2010.0
# ...                                               ...      ...     ...
# 15646                       Championship Manager 2010       PC  2009.0
# 16193                            Vin Diesel: Wheelman      PS3  2009.0
# 16329                         Midway Arcade Treasures      PS2  2003.0
# 16491                                   Mortal Kombat      PSV  2012.0
# 16577                            Gex: Enter the Gecko       PS  1998.0
#
#            Genre                               Publisher  NA_Sales EU_Sales  \
# 0         Action                               Destineer        40        0
# 1         Action                      Namco Bandai Games       170        0
# 2      Adventure                               Alchemist         0        0
# 3           Misc                               Zoo Games        40        0
# 4       Platform                             D3Publisher       120     0.09
# ...          ...                                     ...       ...      ...
# 15646     Sports                       Eidos Interactive         0     0.01
# 16193     Racing                                 Ubisoft       120     0.15
# 16329       Misc                            Midway Games       720     0.56
# 16491   Fighting  Warner Bros. Interactive Entertainment       470     0.18
# 16577   Platform           BMG Interactive Entertainment       320     0.22
#
#        26930,  6420,  3810,  5570,  9810,  3280,  3740,  9090,  1770,
#         9630,  6060,  4790,  2590,  2480,  2970,  2630,  4740,  9070,
#         3510,  1600,  5030,  3220,  3010,  2220,  2770,  3250,  5800,
#         3590,  2400,  1950,  5080,  2840, 15850,  7030,  4890,  3240,
#         4010,  2320,  3400, 12780,  2210,  3360,  4750,  6760,  3000,
#         4050,  5540,  2750,  3210,  6630,  9430,  3030,  3500,  2700,
#         9540,  6750,  3630,  2790,  4210,  2230,  4520,  2890,  4760,
#        14590,  4180,  4100,  2010])

# %%
df1=data[data.EU_Sales.str.contains(r'[^0-9\.]')]
df1.EU_Sales=df1.EU_Sales.str.replace('K','',regex=True).astype(int)
data=data.drop(index=df1.index)
data.EU_Sales=data.EU_Sales.astype(float)*1000
data.EU_Sales=data.EU_Sales.astype(int)
data=pd.concat([data,df1])

df1=data[data.JP_Sales.str.contains(r'[^0-9\.]')]
df1.JP_Sales=df1.JP_Sales.str.replace('K','',regex=True).astype(int)
data=data.drop(index=df1.index)
data.JP_Sales=data.JP_Sales.astype(float)*1000
data.JP_Sales=data.JP_Sales.astype(int)
data=pd.concat([data,df1])

df1=data[data.Other_Sales.str.contains(r'[^0-9\.]')]
df1.Other_Sales=df1.Other_Sales.str.replace('K','',regex=True).astype(int)
data=data.drop(index=df1.index)
data.Other_Sales=data.Other_Sales.astype(float)*1000
data.Other_Sales=data.Other_Sales.astype(int)
data=pd.concat([data,df1])

data
# Out:
# /var/folders/vd/vty5rfw96l98pjmcyhqfys2h0000gn/T/ipykernel_17442/1378513022.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.EU_Sales=df1.EU_Sales.str.replace('K','',regex=True).astype(int)
# /var/folders/vd/vty5rfw96l98pjmcyhqfys2h0000gn/T/ipykernel_17442/1378513022.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.JP_Sales=df1.JP_Sales.str.replace('K','',regex=True).astype(int)
# /var/folders/vd/vty5rfw96l98pjmcyhqfys2h0000gn/T/ipykernel_17442/1378513022.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.Other_Sales=df1.Other_Sales.str.replace('K','',regex=True).astype(int)
#                                                  Name Platform    Year  \
# 0                        Candace Kane's Candy Factory       DS  2008.0
# 1                                      The Munchables      Wii  2009.0
# 2      Otome wa Oanesama Boku ni Koi Shiteru Portable      PSP  2010.0
# 3                    Deal or No Deal: Special Edition       DS  2010.0
# 4           Ben 10 Ultimate Alien: Cosmic Destruction      PS3  2010.0
# ...                                               ...      ...     ...
# 16387                                 Project Setsuna      PSV  2016.0
# 16590                                 Madden NFL 2005      PS2  2004.0
# 7023                 StarCraft II: Heart of the Swarm       PC  2013.0
# 5583                                  Digimon World 2       PS  2000.0
# 16142                                         DJ Hero      Wii  2009.0
#
#               Genre           Publisher  NA_Sales  EU_Sales  JP_Sales  \
# 0            Action           Destineer        40         0         0
# 1            Action  Namco Bandai Games       170         0         0
# 2         Adventure           Alchemist         0         0        20
# 3              Misc           Zoo Games        40         0         0
# 4          Platform         D3Publisher       120        90         0
# ...             ...                 ...       ...       ...       ...
# 16387  Role-Playing         Square Enix         0         0        50
# 16590        Sports     Electronic Arts      4180       260        10
# 7023       Strategy          Activision       820       650         0
# 5583   Role-Playing  Namco Bandai Games       230       160       160
# 16142          Misc          Activision       470       230         0
#
#        Other_Sales
# 0                0
# 1               10
# 2                0
# 3                0
# 4               40
# ...            ...
# 16387            0
# 16590           80
# 7023           190
# 5583            40
# 16142           70
#
# [16547 rows x 9 columns]

# %%
data_origin[data_origin.Name == 'Madden NFL 2005']
# Out:
#                   Name Platform    Year   Genre        Publisher NA_Sales  \
# 1443   Madden NFL 2005       GC  2004.0  Sports  Electronic Arts     0.54
# 5275   Madden NFL 2005       XB  2004.0  Sports  Electronic Arts     1.61
# 8562   Madden NFL 2005       DS  2004.0  Sports  Electronic Arts     0.24
# 12906  Madden NFL 2005      GBA  2004.0  Sports  Electronic Arts     0.28
# 16591  Madden NFL 2005      PS2  2004.0  Sports  Electronic Arts     4.18
#
#       EU_Sales JP_Sales Other_Sales
# 1443      0.14        0        0.02
# 5275      0.03        0        0.08
# 8562         0        0        0.02
# 12906      0.1        0        0.01
# 16591     0.26     0.01         80K

# %%
data['Total_Sales']=data['NA_Sales']+data['EU_Sales']+data['JP_Sales']+data['Other_Sales']

# %% [markdown]
# ##### data=data.reset_index(drop=True)
# data

# %%
data[data.Year.isnull()].Name
# Out:
# 31                                         Rock Band
# 109       Yu-Gi-Oh! 5D's Wheelie Breakers (JP sales)
# 273      Jewel Link Chronicles: Mountains of Madness
# 358               Majesty 2: The Fantasy Kingdom Sim
# 430                                       Famista 64
#                             ...
# 2527           Maze Craze: A Game of Cops 'n Robbers
# 8350                                         Jet X20
# 14049                                   Breakaway IV
# 15215                        Haven: Call of the King
# 16277                                  Madden NFL 11
# Name: Name, Length: 270, dtype: object

# %%
data[data.Name == "Yu-Gi-Oh! 5D's Wheelie Breakers (JP sales)"]
# Out:
#                                            Name Platform  Year   Genre  \
# 109  Yu-Gi-Oh! 5D's Wheelie Breakers (JP sales)      Wii   NaN  Racing
#
#     Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Total_Sales
# 109   Unknown         0         0        20            0           20

# %%
data_clean_year= data.dropna()
data_clean_year
# Out:
#                                                  Name Platform    Year  \
# 0                        Candace Kane's Candy Factory       DS  2008.0
# 1                                      The Munchables      Wii  2009.0
# 2      Otome wa Oanesama Boku ni Koi Shiteru Portable      PSP  2010.0
# 3                    Deal or No Deal: Special Edition       DS  2010.0
# 4           Ben 10 Ultimate Alien: Cosmic Destruction      PS3  2010.0
# ...                                               ...      ...     ...
# 16387                                 Project Setsuna      PSV  2016.0
# 16590                                 Madden NFL 2005      PS2  2004.0
# 7023                 StarCraft II: Heart of the Swarm       PC  2013.0
# 5583                                  Digimon World 2       PS  2000.0
# 16142                                         DJ Hero      Wii  2009.0
#
#               Genre           Publisher  NA_Sales  EU_Sales  JP_Sales  \
# 0            Action           Destineer        40         0         0
# 1            Action  Namco Bandai Games       170         0         0
# 2         Adventure           Alchemist         0         0        20
# 3              Misc           Zoo Games        40         0         0
# 4          Platform         D3Publisher       120        90         0
# ...             ...                 ...       ...       ...       ...
# 16387  Role-Playing         Square Enix         0         0        50
# 16590        Sports     Electronic Arts      4180       260        10
# 7023       Strategy          Activision       820       650         0
# 5583   Role-Playing  Namco Bandai Games       230       160       160
# 16142          Misc          Activision       470       230         0
#
#        Other_Sales  Total_Sales
# 0                0           40
# 1               10          180
# 2                0           20
# 3                0           40
# 4               40          250
# ...            ...          ...
# 16387            0           50
# 16590           80         4530
# 7023           190         1660
# 5583            40          590
# 16142           70          770
#
# [16277 rows x 10 columns]

# %%
#data.Genre=data.Genre.astype('category')
#data.Platform=data.Platform.astype('category')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16547 entries, 0 to 16142
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Name         16547 non-null  object
#  1   Platform     16547 non-null  object
#  2   Year         16277 non-null  float64
#  3   Genre        16547 non-null  object
#  4   Publisher    16547 non-null  object
#  5   NA_Sales     16547 non-null  int64
#  6   EU_Sales     16547 non-null  int64
#  7   JP_Sales     16547 non-null  int64
#  8   Other_Sales  16547 non-null  int64
#  9   Total_Sales  16547 non-null  int64
# dtypes: float64(1), int64(5), object(4)
# memory usage: 1.4+ MB

# %%
data_clean_year=data_clean_year.reset_index(drop=True)

# %%
data_clean_year.isnull().sum()
# Out:
# Name           0
# Platform       0
# Year           0
# Genre          0
# Publisher      0
# NA_Sales       0
# EU_Sales       0
# JP_Sales       0
# Other_Sales    0
# Total_Sales    0
# dtype: int64

# %%
data_clean_year.Year=data_clean_year.Year.astype(int)
data_clean_year.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16277 entries, 0 to 16276
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Name         16277 non-null  object
#  1   Platform     16277 non-null  object
#  2   Year         16277 non-null  int64
#  3   Genre        16277 non-null  object
#  4   Publisher    16277 non-null  object
#  5   NA_Sales     16277 non-null  int64
#  6   EU_Sales     16277 non-null  int64
#  7   JP_Sales     16277 non-null  int64
#  8   Other_Sales  16277 non-null  int64
#  9   Total_Sales  16277 non-null  int64
# dtypes: int64(6), object(4)
# memory usage: 1.2+ MB

# %% [markdown]
# > ## 2.3 Year

# %%
data.groupby('Year',as_index=False).sum()
# Out:
#       Year  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Total_Sales
# 0      0.0        60        40       200           10          310
# 1      1.0      1110       870         0          290         2270
# 2      2.0        70        50        70           20          210
# 3      3.0      2500      1600       260          460         4820
# 4      4.0       660       240        50           60         1010
# ..     ...       ...       ...       ...          ...          ...
# 57  2014.0    130510    125109     39070        39650       334339
# 58  2015.0    101820     96900     33210        29650       261580
# 59  2016.0     21360     24650     13280         7090        66380
# 60  2017.0         0         0        50            0           50
# 61  2020.0       270         0         0           20          290
#
# [62 rows x 6 columns]

# %% [markdown]
# ---

# %%
data_clean_year.Year.unique()
# Out:
# array([2008, 2009, 2010, 2005, 2011, 2007, 2003, 2006, 2014, 2015, 2002,
#        1997, 2013, 1996, 2004, 2000, 1984, 1998, 2001, 2016, 1985, 1999,
#           9,   97, 1995, 1993, 2012, 1987, 1982,   11, 1994, 1990,   15,
#        1992, 1991, 1983, 1988, 1981,    3, 1989,   96,    6,    8, 1986,
#           1,    5,    4,   10,   98,    7,   16,   86,   14,   95, 2017,
#        1980,    2,   13,    0,   12,   94, 2020])

# %%
data_clean_year.Year=data_clean_year.Year.replace(9,2009)
data_clean_year.Year=data_clean_year.Year.replace(97,1997)
data_clean_year.Year=data_clean_year.Year.replace(15,2015)
data_clean_year.Year=data_clean_year.Year.replace(11,2011)
data_clean_year.Year=data_clean_year.Year.replace(3,2003)
data_clean_year.Year=data_clean_year.Year.replace(96,1996)
data_clean_year.Year=data_clean_year.Year.replace(6,2006)
data_clean_year.Year=data_clean_year.Year.replace(8,2008)
data_clean_year.Year=data_clean_year.Year.replace(1,2001)
data_clean_year.Year=data_clean_year.Year.replace(5,2005)
data_clean_year.Year=data_clean_year.Year.replace(4,2004)
data_clean_year.Year=data_clean_year.Year.replace(10,2010)
data_clean_year.Year=data_clean_year.Year.replace(98,1998)
data_clean_year.Year=data_clean_year.Year.replace(7,2007)
data_clean_year.Year=data_clean_year.Year.replace(16,2016)
data_clean_year.Year=data_clean_year.Year.replace(86,1986)
data_clean_year.Year=data_clean_year.Year.replace(14,2014)
data_clean_year.Year=data_clean_year.Year.replace(95,1995)
data_clean_year.Year=data_clean_year.Year.replace(2,2002)
data_clean_year.Year=data_clean_year.Year.replace(13,2013)
data_clean_year.Year=data_clean_year.Year.replace(0,2000)
data_clean_year.Year=data_clean_year.Year.replace(12,2012)
data_clean_year.Year=data_clean_year.Year.replace(94,1994)
data_clean_year.Year.unique()
# Out:
# array([2008, 2009, 2010, 2005, 2011, 2007, 2003, 2006, 2014, 2015, 2002,
#        1997, 2013, 1996, 2004, 2000, 1984, 1998, 2001, 2016, 1985, 1999,
#        1995, 1993, 2012, 1987, 1982, 1994, 1990, 1992, 1991, 1983, 1988,
#        1981, 1989, 1986, 2017, 1980, 2020])

# %% [markdown]
# # 3. EDA

# %% [markdown]
# ># 3.1 Sales by Platform

# %%
data.groupby('Platform').sum().sort_values(by=['Total_Sales'], ascending=False)
# Out:
#                Year  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Total_Sales
# Platform
# PS2       4227711.0    579458    338689    135760       190740      1244647
# X360      2466178.0    600499    280480     12420        85490       978889
# PS3       2596057.0    391359    342950     79340       141589       955238
# Wii       2569512.0    505440    264809     66840        79890       916979
# DS        4243461.0    390110    194650    175520        60480       820760
# PS        2354131.0    335587    212970    139130        40750       728437
# GBA       1612601.0    187370     75190     47330         7730       317620
# PSP       2382411.0    108400     68240     76620        42140       295400
# PS4        669027.0     95800    122940     14040        43000       275780
# PC        1876248.0     93269    138840       170        24770       257049
# GB         191608.0    114320     47820     85120         8200       255460
# XB        1590906.0    183870     59670      1380         8550       253470
# NES        192841.0    125939     21150     98650         5310       251049
# 3DS        996518.0     73698     54470     93010        11840       233018
# N64        621740.0    138450     40699     33930         4350       217429
# SNES       470829.0     61230     19040    116550         3220       200040
# GC        1077840.0    133260     38660     21140         5160       198220
# XOne       427135.0     83190     45629       340        11920       141079
# 2600       227948.0     90140      5440         0          900        96480
# WiiU       287944.0     38320     24230     12790         6450        81790
# PSV        817770.0     16200     16330     20910         8450        61890
# SAT        339613.0       720       540     32260           70        33590
# GEN         53812.0     19270      5520      2670          890        28350
# DC         103997.0      5430      1690      8560          270        15950
# SCD         11963.0      1000       360       450           50         1860
# NG          23934.0         0         0      1440            0         1440
# WS          12000.0         0         0      1420            0         1420
# TG16         3990.0         0         0       160            0          160
# 3DO          5984.0         0         0       100            0          100
# GG           1992.0         0         0        40            0           40
# PCFX         1996.0         0         0        30            0           30

# %% [markdown]
# > # 3.2 Sales by Genre

# %%
data.groupby('Genre', as_index=False).sum()
# Out:
#            Genre       Year  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 0         Action  6481945.0    874808    522158    157900       186449
# 1      Adventure  2542424.0    105660     64050     51950        16810
# 2       Fighting  1662060.0    223198    101220     87340        36640
# 3           Misc  3402377.0    408050    212360    105270        74040
# 4       Platform  1735533.0    446440    201610    130650        51530
# 5         Puzzle  1120973.0    123350     50730     56870        12520
# 6         Racing  2426113.0    357188    237100     56400        77100
# 7   Role-Playing  2926353.0    319540    183580    344950        56960
# 8        Shooter  2543679.0    581919    313049     38260       102650
# 9     Simulation  1693571.0    182958    113350     63700        31480
# 10        Sports  4590719.0    680518    376479    135370       134670
# 11      Strategy  1333950.0     68700     45320     49460        11360
#
#     Total_Sales
# 0       1741315
# 1        238470
# 2        448398
# 3        799720
# 4        830230
# 5        243470
# 6        727788
# 7        905030
# 8       1035878
# 9        391488
# 10      1327037
# 11       174840

# %%
NA_Genre_Chart=data.groupby('Genre', as_index=False)['NA_Sales'].sum().sort_values(by=['NA_Sales'],ascending=False).reset_index(drop=True)
print('북미지역 장르별 판매량\n', NA_Genre_Chart)
# Out:
# 북미지역 장르별 판매량
#             Genre  NA_Sales
# 0         Action    874808
# 1         Sports    680518
# 2        Shooter    581919
# 3       Platform    446440
# 4           Misc    408050
# 5         Racing    357188
# 6   Role-Playing    319540
# 7       Fighting    223198
# 8     Simulation    182958
# 9         Puzzle    123350
# 10     Adventure    105660
# 11      Strategy     68700

# %%
EU_Genre_Chart=data.groupby('Genre', as_index=False)['EU_Sales'].sum().sort_values(by=['EU_Sales'],ascending=False).reset_index(drop=True)
print('유럽지역 장르별 판매량\n', EU_Genre_Chart)
# Out:
# 유럽지역 장르별 판매량
#             Genre  EU_Sales
# 0         Action    522158
# 1         Sports    376479
# 2        Shooter    313049
# 3         Racing    237100
# 4           Misc    212360
# 5       Platform    201610
# 6   Role-Playing    183580
# 7     Simulation    113350
# 8       Fighting    101220
# 9      Adventure     64050
# 10        Puzzle     50730
# 11      Strategy     45320

# %%
JP_Genre_Chart=data.groupby('Genre', as_index=False)['JP_Sales'].sum().sort_values(by=['JP_Sales'],ascending=False).reset_index(drop=True)
print('일본지역 장르별 판매량\n', JP_Genre_Chart)
# Out:
# 일본지역 장르별 판매량
#             Genre  JP_Sales
# 0   Role-Playing    344950
# 1         Action    157900
# 2         Sports    135370
# 3       Platform    130650
# 4           Misc    105270
# 5       Fighting     87340
# 6     Simulation     63700
# 7         Puzzle     56870
# 8         Racing     56400
# 9      Adventure     51950
# 10      Strategy     49460
# 11       Shooter     38260

# %%
ETC_Genre_Chart=data.groupby('Genre', as_index=False)['Other_Sales'].sum().sort_values(by=['Other_Sales'],ascending=False).reset_index(drop=True)
print('기타지역 장르별 판매량\n', ETC_Genre_Chart)
# Out:
# 기타지역 장르별 판매량
#             Genre  Other_Sales
# 0         Action       186449
# 1         Sports       134670
# 2        Shooter       102650
# 3         Racing        77100
# 4           Misc        74040
# 5   Role-Playing        56960
# 6       Platform        51530
# 7       Fighting        36640
# 8     Simulation        31480
# 9      Adventure        16810
# 10        Puzzle        12520
# 11      Strategy        11360

# %%
Total_Genre_Chart=data.groupby('Genre', as_index=False)['Total_Sales'].sum().sort_values(by=['Total_Sales'],ascending=False).reset_index(drop=True)
print('장르별 총 판매량\n', Total_Genre_Chart)
# Out:
# 장르별 총 판매량
#             Genre  Total_Sales
# 0         Action      1741315
# 1         Sports      1327037
# 2        Shooter      1035878
# 3   Role-Playing       905030
# 4       Platform       830230
# 5           Misc       799720
# 6         Racing       727788
# 7       Fighting       448398
# 8     Simulation       391488
# 9         Puzzle       243470
# 10     Adventure       238470
# 11      Strategy       174840

# %%
Total_Genre_Chart['Genre']
# Out:
# 0           Action
# 1           Sports
# 2          Shooter
# 3     Role-Playing
# 4         Platform
# 5             Misc
# 6           Racing
# 7         Fighting
# 8       Simulation
# 9           Puzzle
# 10       Adventure
# 11        Strategy
# Name: Genre, dtype: object

# %%
group_genre=pd.DataFrame({'북미 판매량':NA_Genre_Chart['Genre'],'유럽 판매량':EU_Genre_Chart['Genre'],'일본 판매량':JP_Genre_Chart['Genre'],'기타지역 판매량':ETC_Genre_Chart['Genre'],'총 판매량':Total_Genre_Chart['Genre']})

# %%
group_genre
# Out:
#           북미 판매량        유럽 판매량        일본 판매량      기타지역 판매량         총 판매량
# 0         Action        Action  Role-Playing        Action        Action
# 1         Sports        Sports        Action        Sports        Sports
# 2        Shooter       Shooter        Sports       Shooter       Shooter
# 3       Platform        Racing      Platform        Racing  Role-Playing
# 4           Misc          Misc          Misc          Misc      Platform
# 5         Racing      Platform      Fighting  Role-Playing          Misc
# 6   Role-Playing  Role-Playing    Simulation      Platform        Racing
# 7       Fighting    Simulation        Puzzle      Fighting      Fighting
# 8     Simulation      Fighting        Racing    Simulation    Simulation
# 9         Puzzle     Adventure     Adventure     Adventure        Puzzle
# 10     Adventure        Puzzle      Strategy        Puzzle     Adventure
# 11      Strategy      Strategy       Shooter      Strategy      Strategy

# %% [markdown]
# > ## 3.3 Year

# %%
group_year=data_clean_year.groupby(['Year','Genre']).sum()

# %%
pd.set_option('display.max_rows',None)

# %%
group_year.sort_values(by=['Year','Total_Sales'], ascending=[True, False])
# Out:
#                    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Total_Sales
# Year Genre
# 1980 Shooter           6560       430         0           80         7070
#      Misc              2530       150         0           20         2700
#      Fighting           720        40         0           10          770
#      Action             320        20         0            0          340
# 1981 Action           13860       810         0          120        14790
#      Shooter           9370       560         0           90        10020
#      Platform          6470       370         0           80         6920
#      Puzzle            2090       130         0           30         2250
#      Sports             740        40         0            0          780
#      Racing             450        30         0            0          480
#      Simulation         420        20         0            0          440
# 1982 Puzzle            9350       580         0          110        10040
#      Action            6070       380         0           50         6500
#      Platform          4690       280         0           60         5030
#      Shooter           3550       210         0           50         3810
#      Racing            1470        90         0           10         1570
#      Sports             980        60         0           20         1060
#      Misc               810        50         0           10          870
# 1983 Platform          2800       430      3620           80         6930
#      Sports             730       100      2350           20         3200
#      Action            2670       170         0           20         2860
#      Misc                10         0      2130            0         2140
#      Puzzle             720        50         0           10          780
#      Shooter            450        30         0           10          490
#      Adventure          380        20         0            0          400
# min     1980.000000      0.000000      0.000000      0.000000      0.000000
# 25%     2003.000000      0.000000      0.000000      0.000000      0.000000
# 50%     2007.000000     80.000000     20.000000      0.000000     10.000000
# 75%     2010.000000    240.000000    110.000000     40.000000     40.000000
# max     2020.000000  41490.000000  29020.000000  10220.000000  10570.000000
#
#         Total_Sales
# count  16277.000000
# mean     538.409658
# std     1562.287737
# min        0.000000
# 25%       60.000000
# 50%      170.000000
# 75%      480.000000
# max    82740.000000

# %%
bins = [1980, 2003, 2007, 2010, 2020]
labels = ['Before 2003', 'Before 2007', 'Before 2010', 'After 2010']
data_clean_year['year_label'] = pd.cut(x=data_clean_year['Year'], bins=bins, labels = labels)
data_clean_year.head()
# Out:
#                                              Name Platform  Year      Genre  \
# 0                    Candace Kane's Candy Factory       DS  2008     Action
# 1                                  The Munchables      Wii  2009     Action
# 2  Otome wa Oanesama Boku ni Koi Shiteru Portable      PSP  2010  Adventure
# 3                Deal or No Deal: Special Edition       DS  2010       Misc
# 4       Ben 10 Ultimate Alien: Cosmic Destruction      PS3  2010   Platform
#
#             Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Total_Sales  \
# 0           Destineer        40         0         0            0           40
# 1  Namco Bandai Games       170         0         0           10          180
# 2           Alchemist         0         0        20            0           20
# 3           Zoo Games        40         0         0            0           40
# 4         D3Publisher       120        90         0           40          250
#
#     year_label
# 0  Before 2010
# 1  Before 2010
# 2  Before 2010
# 3  Before 2010
# 4  Before 2010

# %%
data_year_label=data_clean_year.groupby(['year_label','Genre']).sum().sort_values(by=['year_label','Total_Sales'], ascending=[True,False])
data_year_label
# Out:
#                              Year  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# year_label  Genre
# Before 2003 Platform       777441    268410    100450     88280        18140
#             Action        1207139    242610    121829     45840        24830
#             Sports        1631507    199520     90830     78000        23880
#             Role-Playing   703527     95970     55550    159610        13330
#             Racing        1029971    170409     92490     36780        19390
#             Shooter        743435    146379     53039     17360        11190
#             Fighting       681488    105208     47750     54260         9830
#             Misc           525826     68010     33910     32100         6510
#             Puzzle         287487     68070     14440     35050         2940
#             Simulation     371825     47709     23770     30730         5280
#             Strategy       435788     33850     17650     32150         3380
#             Adventure      375787     29850     21080     20740         3020
# Before 2007 Sports        1063019    193319     95379     26240        40060
#             Action        1426034    185720     79110     23040        46280
#             Misc           922626    117900     70080     37590        26230
#             Shooter        675834    119970     52860      5390        19500
#             Role-Playing   685964     76080     38180     52640        11210
#             Racing         613703     90159     49590      8180        27090
#             Platform       489292     83750     39160     19300        13170
#             Simulation     427276     62750     40260     15000        12740
#             Fighting       375051     40080     16580      9960         9980
#             Puzzle         328967     24600     18490     15220         4930
#             Adventure      473380     28280     12380      8140         4280
#             Strategy       338987     11270      5760      6800         2260
# Before 2010 Action        1438451    204019    113440     25920        47900
#             Sports        1143106    168539     98160     19600        39550
#             Misc          1239543    141800     65220     17240        27220
#             Shooter        512293    117040     61360      4010        24380
#             Role-Playing   638853     72860     33360     58250        13740
#             Racing         445973     62770     51950      5750        19280
#             Platform       243058     54910     30900     10880        11890
#             Simulation     646861     55510     30710      6270         9520
#             Fighting       301333     43240     18980     10690         9560
#             Adventure      924127     29450     16420     11270         5010
#             Puzzle         377673     26070     13970      3060         3860
#             Strategy       337515     15240     13620      5570         3600
# After 2010  Action        2436041    226109    199239     61810        64979
#             Shooter        632057    184530    142540     11420        46710
#             Sports         772987    105880     86600     10920        28860
#             Role-Playing   914009     73850     56010     72430        18450
#             Misc           726462     70050     40840     17250        12760
#             Platform       241542     38310     30140     12070         8250
#             Racing         356266     31360     41000      5610        10750
#             Fighting       314008     31100     16550     12230         6770
#             Simulation     257609     15459     18430     11540         3780
#             Adventure      777030     14340     13830     11740         4390
#             Strategy       231460      7530      7890      4580         1990
#             Puzzle         142846      2840      3580      2910          710
#
#                           Total_Sales
# year_label  Genre
# Before 2003 Platform           475280
#             Action             435109
#             Sports             392230
#             Role-Playing       324460
#             Racing             319069
#             Shooter            227968
#             Fighting           217048
#             Misc               140530
#             Puzzle             120500
#             Simulation         107489
#             Strategy            87030
#             Adventure           74690
# Before 2007 Sports             354998
#             Action             334150
#             Misc               251800
#             Shooter            197720
#             Role-Playing       178110
#             Racing             175019
#             Platform           155380
#             Simulation         130750
#             Fighting            76600
#             Puzzle              63240
#             Adventure           53080
#             Strategy            26090
# Before 2010 Action             391279
#             Sports             325849
#             Misc               251480
#             Shooter            206790
#             Role-Playing       178210
#             Racing             139750
#             Platform           108580
#             Simulation         102010
#             Fighting            82470
#             Adventure           62150
#             Puzzle              46960
#             Strategy            38030
# After 2010  Action             552137
#             Shooter            385200
#             Sports             232260
#             Role-Playing       220740
#             Misc               140900
#             Platform            88770
#             Racing              88720
#             Fighting            66650
#             Simulation          49209
#             Adventure           44300
#             Strategy            21990
#             Puzzle              10040

# %%
#연도 구간별 판매 장르 순위
bins2 = [1980, 1985, 1990, 1995, 2000, 2005, 2010, 2015, 2020]
labels2 = ['1980~1985', '1985~1990', '1990~1995', '1995~2000','2000~2005','2005~2010','2010~2015','2015~2020']
data_clean_year1=data_clean_year.copy()
data_clean_year1['year_label'] = pd.cut(x=data_clean_year['Year'], bins=bins2, labels = labels2)
data_clean_year1=data_clean_year1.groupby(['year_label','Genre']).sum().sort_values(by=['year_label','Total_Sales'], ascending=[True,False])

# %% [markdown]
# # 4 Analysis

# %% [markdown]
# > ## 4.1 지역 별로 선호하는 게임 장르가 다를까

# %% [markdown]
# >> 가설 1. 일본 지역을 제외한 지역의 게임 선호도는 유사하다
# >>> H0: 지역 별 게임 선호도는 유사하지 않다
# >>> Ha: 일본 지역을 제외한 지역의 게임 선호도는 유사하다
#
#
# >> 가설 2. 일본 지역의 게임 선호도는 다른 지역과 다르다
#
# >>> H0: 일본 지역의 게임 선호도는 다른 지역과 같다
# >>> Ha: 일본 지역의 게임 선호도는 다른 지역과 다르다

# %%
group_genre
# Out:
#           북미 판매량        유럽 판매량        일본 판매량      기타지역 판매량         총 판매량
# 0         Action        Action  Role-Playing        Action        Action
# 1         Sports        Sports        Action        Sports        Sports
# 2        Shooter       Shooter        Sports       Shooter       Shooter
# 3       Platform        Racing      Platform        Racing  Role-Playing
# 4           Misc          Misc          Misc          Misc      Platform
# 5         Racing      Platform      Fighting  Role-Playing          Misc
# 6   Role-Playing  Role-Playing    Simulation      Platform        Racing
# 7       Fighting    Simulation        Puzzle      Fighting      Fighting
# 8     Simulation      Fighting        Racing    Simulation    Simulation
# 9         Puzzle     Adventure     Adventure     Adventure        Puzzle
# 10     Adventure        Puzzle      Strategy        Puzzle     Adventure
# 11      Strategy      Strategy       Shooter      Strategy      Strategy

# %%
data_x_jp=data.copy()
data_x_jp['Total_Sales_x_JP']=data['NA_Sales']+data['EU_Sales']+data['Other_Sales']
Total_x_jp_Genre_Chart=data_x_jp.groupby('Genre', as_index=False)['Total_Sales_x_JP'].sum().sort_values(by=['Total_Sales_x_JP'],ascending=False).reset_index(drop=True)
group_genre2=pd.DataFrame({'북미 판매량':NA_Genre_Chart['Genre'],'유럽 판매량':EU_Genre_Chart['Genre'],'기타지역 판매량':ETC_Genre_Chart['Genre'],'일본 시장 제외 총 판매량':Total_x_jp_Genre_Chart['Genre']})
group_genre2
# Out:
#           북미 판매량        유럽 판매량      기타지역 판매량 일본 시장 제외 총 판매량
# 0         Action        Action        Action         Action
# 1         Sports        Sports        Sports         Sports
# 2        Shooter       Shooter       Shooter        Shooter
# 3       Platform        Racing        Racing       Platform
# 4           Misc          Misc          Misc           Misc
# 5         Racing      Platform  Role-Playing         Racing
# 6   Role-Playing  Role-Playing      Platform   Role-Playing
# 7       Fighting    Simulation      Fighting       Fighting
# 8     Simulation      Fighting    Simulation     Simulation
# 9         Puzzle     Adventure     Adventure         Puzzle
# 10     Adventure        Puzzle        Puzzle      Adventure
# 11      Strategy      Strategy      Strategy       Strategy

# %%
Total_x_jp_Genre_Chart
# Out:
#            Genre  Total_Sales_x_JP
# 0         Action           1583415
# 1         Sports           1191667
# 2        Shooter            997618
# 3       Platform            699580
# 4           Misc            694450
# 5         Racing            671388
# 6   Role-Playing            560080
# 7       Fighting            361058
# 8     Simulation            327788
# 9         Puzzle            186600
# 10     Adventure            186520
# 11      Strategy            125380

# %%
na_genre_chart_df=pd.DataFrame(NA_Genre_Chart).set_index('Genre')
eu_genre_chart_df=pd.DataFrame(EU_Genre_Chart).set_index('Genre')
etc_genre_chart_df=pd.DataFrame(ETC_Genre_Chart).set_index('Genre')
xjp_genre_chart_df=pd.DataFrame(Total_x_jp_Genre_Chart).set_index('Genre')


from sklearn import preprocessing

std_scaler = preprocessing.StandardScaler()
#min_max_scaler = preprocessing.MinMaxScaler()
#na_genre_chart=min_max_scaler.fit_transform(NA_Genre_Chart['NA_Sales'])
#na_genre_chart=min_max_scaler.fit_transform(na_genre_chart_df)
na_genre_chart=std_scaler.fit_transform(na_genre_chart_df)

std_scaler = preprocessing.StandardScaler()
#min_max_scaler = preprocessing.MinMaxScaler()
#eu_genre_chart=min_max_scaler.fit_transform(EU_Genre_Chart['EU_Sales'])
#eu_genre_chart=min_max_scaler.fit_transform(eu_genre_chart_df)
eu_genre_chart=std_scaler.fit_transform(eu_genre_chart_df)

std_scaler = preprocessing.StandardScaler()
#min_max_scaler = preprocessing.MinMaxScaler()
#etc_genre_chart=min_max_scaler.fit_transform(ETC_Genre_Chart['Other_Sales'])
#etc_genre_chart=min_max_scaler.fit_transform(etc_genre_chart_df)
etc_genre_chart=std_scaler.fit_transform(etc_genre_chart_df)

std_scaler = preprocessing.StandardScaler()
#min_max_scaler = preprocessing.MinMaxScaler()
#xjp_genre_chart=min_max_scaler.fit_transform(Total_x_jp_Genre_Chart['Total_Sales_x_JP'])
#xjp_genre_chart=min_max_scaler.fit_transform(xjp_genre_chart_df)
xjp_genre_chart=std_scaler.fit_transform(xjp_genre_chart_df)

na_genre_chart
# Out:
# array([[ 2.13832384],
#        [ 1.32442007],
#        [ 0.91137721],
#        [ 0.34383968],
#        [ 0.18301943],
#        [-0.0300475 ],
#        [-0.18775942],
#        [-0.59134744],
#        [-0.75991755],
#        [-1.00962251],
#        [-1.08372801],
#        [-1.23855781]])

# %%
na_genre_chart_df=pd.DataFrame(na_genre_chart, index=NA_Genre_Chart['Genre'], columns=['NA_Sales'])
eu_genre_chart_df=pd.DataFrame(eu_genre_chart, index=EU_Genre_Chart['Genre'], columns=['EU_Sales'])
etc_genre_chart_df=pd.DataFrame(etc_genre_chart, index=ETC_Genre_Chart['Genre'], columns=['Other_Sales'])
xjp_genre_chart_df=pd.DataFrame(xjp_genre_chart, index=Total_x_jp_Genre_Chart['Genre'], columns=['Tot_except_jp_Sales'])

na_genre_chart_df
# Out:
#               NA_Sales
# Genre
# Action        2.138324
# Sports        1.324420
# Shooter       0.911377
# Platform      0.343840
# Misc          0.183019
# Racing       -0.030047
# Role-Playing -0.187759
# Fighting     -0.591347
# Simulation   -0.759918
# Puzzle       -1.009623
# Adventure    -1.083728
# Strategy     -1.238558

# %% [markdown]
# > ## 4.2 연도 별로 선호하는 게임 장르가 다를까

# %% [markdown]
# >> ### 가설 1. 연도 별로 게임 장르 선호도는 변한다
# >>> #### H0: 연도 별 게임 장르 선호도는 같다
# >>> #### Ha: 연도 별 게임 장르 선호도는 같지 않다
#
#
# >> ### 분석. Action - Shooter - Sports - RolePlaying 순으로 판매량이 높았다.

# %%
data_clean_year1
# Out:
#                             Year  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# year_label Genre
# 1980~1985  Platform        35692     43890      4850     12980         1020
#            Shooter         39640     41810      1790      2170          650
#            Action         105036     25040      1930      2270          280
#            Puzzle          25783     14180      1130      3890          220
#            Sports          19824      4330       820      7900          120
#            Racing          11897      4220       610      3090           80
#            Misc             5949       820        50      3580           10
#            Fighting         1985         0         0      1050            0
#            Simulation       3966       420        50         0           10
#            Adventure        1983       380        20         0            0
#            Role-Playing        0         0         0         0            0
#            Strategy            0         0         0         0            0
# 1985~1990  Platform        35779     44590     12380     23750         1780
#            Puzzle          15913     32640      5100     10510         1070
#            Action          29814     16810      3310      7050          460
#            Sports          29819      6640      2220     11580          280
#            Role-Playing    21869      1140         0     17100         1530
#            Racing           7954      5700      1950      2080          620
#            Shooter         15895      2470       610      3130           70
#            Fighting         3974      2799       650      1870          100
#            Adventure        1987      2190       500      1610           80
#            Racing          40320       330      1140        10          190
#            Misc            36288       220        90       810           30
#            Simulation      20164       270        90       300           20
#            Strategy        20160       110       320        50           40
#            Puzzle              0         0         0         0            0
#
#                          Total_Sales
# year_label Genre
# 1980~1985  Platform            62740
#            Shooter             46420
#            Action              29520
#            Puzzle              19420
#            Sports              13170
#            Racing               8000
#            Misc                 4460
#            Fighting             1050
#            Simulation            480
#            Adventure             400
#            Role-Playing            0
#            Strategy                0
# 1985~1990  Platform            82500
#            Puzzle              49320
#            Action              27630
#            Sports              20720
#            Role-Playing        19770
#            Racing              10350
#            Shooter              6280
#            Fighting             5419
#            Adventure            4380
#            Misc                 1280
#            Simulation           1160
#            Strategy                0
# 1990~1995  Platform            85170
#            Fighting            47680
#            Role-Playing        37110
#            Sports              24940
#            Adventure           19000
#            Racing              18820
#            Shooter             17800
#            Action              17540
#            Puzzle              15470
#            Misc                14570
#            Strategy            12220
#            Simulation          11370
# 1995~2000  Role-Playing       170180
#            Sports             160660
#            Action             149110
#            Racing             143739
#            Platform           116770
#            Fighting            96089
#            Misc                64410
#            Shooter             57918
#            Strategy            53810
#            Simulation          42910
#            Adventure           28760
#            Puzzle              21310
# 2000~2005  Action             372979
#            Sports             293379
#            Racing             240169
#            Platform           198250
#            Shooter            188040
#            Role-Playing       179860
#            Misc               148100
#            Simulation         111739
#            Fighting           103250
#            Puzzle              43650
#            Adventure           39310
#            Strategy            33480
# 2005~2010  Action             563759
#            Sports             560208
#            Misc               410990
#            Shooter            316020
#            Role-Playing       273860
#            Racing             212760
#            Platform           193810
#            Simulation         172590
#            Fighting           122630
#            Adventure           98070
#            Puzzle              81530
#            Strategy            51640
# 2010~2015  Action             532277
#            Shooter            367030
#            Sports             217630
#            Role-Playing       213950
#            Misc               139750
#            Racing              87050
#            Platform            86690
#            Fighting            62800
#            Simulation          48529
#            Adventure           42490
#            Strategy            21470
#            Puzzle              10040
# 2015~2020  Action              19860
#            Shooter             18170
#            Sports              14630
#            Role-Playing         6790
#            Fighting             3850
#            Platform             2080
#            Adventure            1810
#            Racing               1670
#            Misc                 1150
#            Simulation            680
#            Strategy              520
#            Puzzle                  0

# %%
data_clean_year[data_clean_year.Year > 2010].groupby(['Year','Genre']).sum().sort_values(by=['Year','Total_Sales'], ascending=[True, False])
# Out:
#                    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Total_Sales
# Year Genre
# 2011 Action           53729     41040     10820        13410       118999
#      Shooter          49820     35310      2690        11530        99350
#      Sports           27450     19860      3080         6670        57060
#      Misc             32070     14040      4740         4920        55770
#      Role-Playing     19780     14100     14430         5010        53320
#      Racing           14610     13520      3120         3720        34970
#      Platform         13060      8860      3490         2710        28120
#      Fighting         11490      5570      2930         2120        22110
#      Adventure         5890      4690      3780         1520        15880
#      Simulation        7490      5210      1230         1400        15330
#      Strategy          3360      2910      1900          860         9030
#      Puzzle            1680      2190       770          460         5100
# 2012 Action           52160     42260     12250        14139       120809
#      Shooter          35060     26340      2620         8820        72840
#      Role-Playing     17850     11970     14390         3560        47770
#      Sports           16400      8830      2590         3080        30900
#      Misc             10990      6630      3660         1650        22930
#      Platform          7320      5880      3840         1520        18560
#      Racing            4380      7580       200         2270        14430
#      Simulation        3089      3620      5860          800        13369
#      Fighting          4340      2430      1790          970         9530
#      Adventure         1780      1310      2370          440         5900
#      Strategy           940       990      1110          290         3330
#      Puzzle             300       420       960           60         1740
# 2013 Action           53790     45210     10880        15330       125210
#      Shooter          30700     23150      1730         7150        62730
#      Sports           19180     15160      2150         5050        41540
#      Role-Playing      7920      4890     15520         2210        30540
#      Misc             12530      7500      3580         2050        25660
#      Platform         11620      9090      2080         2300        25090
#      Racing            4210      6320       540         1950        13020
#      Simulation        2260      3560      2200          660         8680
#      Fighting          3180      1950      1280          820         7230
#      Adventure         1630      1970      2220          790         6610
#      Strategy          2390      2470       820          640         6320
#      Puzzle             190       480       250           80         1000
# 2014 Action           38730     40479      6500        13300        99009
#      Shooter          30720     25810      1080         8380        65990
#      Sports           19820     18700      1600         6520        46640
#      Role-Playing     13560     11240     17710         3380        45890
#      Misc              9430      8870      2360         3070        23730
#      Racing            5860      7700      1460         1690        16710
#      Fighting          6890      3070      4800         1390        16150
#      Platform          3020      3630      1260          960         8870
#      Adventure         1940      2110      1360          680         6090
#      Simulation        1220      3440       370          510         5540
#      Puzzle             620       380       410          100         1510
#      Strategy           160       220       550           40          970
# 2015 Action           21830     23890     15560         6970        68250
#      Shooter          30790     24230      2690         8410        66120
#      Sports           18460     16690       720         5620        41490
#      Role-Playing     13350     12520      6710         3850        36430
#      Misc              4810      3710      2100         1040        11660
#      Adventure         2760      3360      1040          850         8010
#      Racing            1970      4740       280          930         7920
#      Fighting          3600      2380       790         1010         7780
#      Platform          2500      1810      1290          450         6050
#      Simulation        1130      2510      1580          390         5610
#      Strategy           570       980       150          120         1820
#      Puzzle              50       110       520           10          690
# 2016 Action            5870      6360      5790         1830        19850
#      Shooter           7440      7700       610         2420        18170
#      Sports            4570      7360       780         1920        14630
#      Role-Playing      1390      1290      3630          440         6750
#      Fighting          1600      1150       640          460         3850
#      Platform           790       870       110          310         2080
#      Adventure          340       390       970          110         1810
#      Racing             330      1140        10          190         1670
#      Misc               220        90       810           30         1150
#      Strategy           110       320        50           40          520
#      Simulation           0        90       300            0          390
# 2017 Role-Playing         0         0        40            0           40
#      Action               0         0        10            0           10
# 2020 Simulation         270         0         0           20          290

# %% [markdown]
# > ## 4.3 출고량이 높은 게임 분석

# %%
NA_MAX=data[data.NA_Sales == data.NA_Sales.max()]
NA_MAX
# Out:
#             Name Platform    Year   Genre Publisher  NA_Sales  EU_Sales  \
# 2908  Wii Sports      Wii  2006.0  Sports  Nintendo     41490     29020
#
#       JP_Sales  Other_Sales  Total_Sales
# 2908      3770         8460        82740

# %%
EU_MAX=data[data.EU_Sales == data.EU_Sales.max()]
EU_MAX
# Out:
#             Name Platform    Year   Genre Publisher  NA_Sales  EU_Sales  \
# 2908  Wii Sports      Wii  2006.0  Sports  Nintendo     41490     29020
#
#       JP_Sales  Other_Sales  Total_Sales
# 2908      3770         8460        82740

# %%
ETC_MAX=data[data.Other_Sales == data.Other_Sales.max()]
ETC_MAX
# Out:
#                                 Name Platform    Year   Genre  \
# 14668  Grand Theft Auto: San Andreas      PS2  2004.0  Action
#
#                   Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 14668  Take-Two Interactive      9430       400       410        10570
#
#        Total_Sales
# 14668        20810

# %%
JP_MAX=data[data.JP_Sales == data.JP_Sales.max()]
JP_MAX
# Out:
#                           Name Platform    Year         Genre Publisher  \
# 7829  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
#
#       NA_Sales  EU_Sales  JP_Sales  Other_Sales  Total_Sales
# 7829     11270      8890     10220         1000        31380

# %%
TOT_MAX=data[data.Total_Sales == data.Total_Sales.max()]
TOT_MAX
# Out:
#             Name Platform    Year   Genre Publisher  NA_Sales  EU_Sales  \
# 2908  Wii Sports      Wii  2006.0  Sports  Nintendo     41490     29020
#
#       JP_Sales  Other_Sales  Total_Sales
# 2908      3770         8460        82740

# %%
top_sales=data.sort_values(by='Total_Sales',ascending=False).reset_index(drop=True).head(20)
top_sales
# Out:
#                                             Name Platform    Year  \
# 0                                     Wii Sports      Wii  2006.0
# 1                              Super Mario Bros.      NES  1985.0
# 2                                 Mario Kart Wii      Wii  2008.0
# 3                              Wii Sports Resort      Wii  2009.0
# 4                       Pokemon Red/Pokemon Blue       GB  1996.0
# 5                                         Tetris       GB  1989.0
# 6                          New Super Mario Bros.       DS  2006.0
# 7                                       Wii Play      Wii  2006.0
# 8                      New Super Mario Bros. Wii      Wii  2009.0
# 9                                      Duck Hunt      NES  1984.0
# 10                                    Nintendogs       DS  2005.0
# 11                                 Mario Kart DS       DS  2005.0
# 12                   Pokemon Gold/Pokemon Silver       GB  1999.0
# 13                                       Wii Fit      Wii  2007.0
# 14                                  Wii Fit Plus      Wii  2009.0
# 15                            Kinect Adventures!     X360  2010.0
# 16                            Grand Theft Auto V      PS3  2013.0
# 17                 Grand Theft Auto: San Andreas      PS2  2004.0
# 18                             Super Mario World     SNES  1990.0
# 19  Brain Age: Train Your Brain in Minutes a Day       DS  2005.0
#
#            Genre               Publisher  NA_Sales  EU_Sales  JP_Sales  \
# 0         Sports                Nintendo     41490     29020      3770
# 1       Platform                Nintendo     29080      3580      6810
# 2         Racing                Nintendo     15850     12880      3790
# 3         Sports                Nintendo     15750     11010      3280
# 4   Role-Playing                Nintendo     11270      8890     10220
# 5         Puzzle                Nintendo     23200      2260      4220
# 6       Platform                Nintendo     11380      9230      6500
# 7           Misc                Nintendo     14030      9200      2930
# 8       Platform                Nintendo     14590      7060      4700
# 9        Shooter                Nintendo     26930       630       280
# 10    Simulation                Nintendo      9070     11000      1930
# 11        Racing                Nintendo      9810      7570      4130
# 12  Role-Playing                Nintendo      9000      6180      7200
# 13        Sports                Nintendo      8940      8029      3600
# 14        Sports                Nintendo      9090      8590      2530
# 15          Misc  Microsoft Game Studios     14970      4940       240
# 16        Action    Take-Two Interactive      7010      9270       970
# 17        Action    Take-Two Interactive      9430       400       410
# 18      Platform                Nintendo     12780      3750      3540
# 19          Misc                Nintendo      4750      9260      4160
#
#     Other_Sales  Total_Sales
# 0          8460        82740
# 1           770        40240
# 2          3310        35830
# 3          2960        33000
# 4          1000        31380
# 5           580        30260
# 6          2900        30010
# 7          2850        29010
# 8          2260        28610
# 9           470        28310
# 10         2750        24750
# 11         1920        23430
# 12          710        23090
# 13         2150        22719
# 14         1790        22000
# 15         1670        21820
# 16         4140        21390
# 17        10570        20810
# 18          550        20620
# 19         2050        20220

# %%
plt.figure(figsize=(15,5))
plt.bar(np.arange(len(top_sales.Name[:5]))-0.3, top_sales.NA_Sales[:5], width=0.15, label='North America Sales')
plt.bar(np.arange(len(top_sales.Name[:5]))-0.15, top_sales.EU_Sales[:5], width=0.15, label='Europe Sales')
plt.bar(np.arange(len(top_sales.Name[:5])), top_sales.JP_Sales[:5], width=0.15, label='Japen Sales')
plt.bar(np.arange(len(top_sales.Name[:5]))+0.15, top_sales.Other_Sales[:5], width=0.15, label='ETC Sales')
plt.bar(np.arange(len(top_sales.Name[:5]))+0.3, top_sales.Total_Sales[:5], width=0.15, label='Total Sales')
plt.xticks(np.arange(len(top_sales.Name[:5])),top_sales.Name[:5])

plt.legend()
plt.xlabel('Game', fontsize=15)
plt.ylabel('# Sales[K]', fontsize=15)
plt.title('Top sold game', fontsize=18)
# Out:
# Text(0.5, 1.0, 'Top sold game')

# %%
top_sales_x_nintendo=data[data.Publisher != 'Nintendo'].sort_values(by='Total_Sales',ascending=False).reset_index(drop=True).head(50)
top_sales_x_nintendo
# Out:
#                                       Name Platform    Year         Genre  \
# 0                       Kinect Adventures!     X360  2010.0          Misc
# 1                       Grand Theft Auto V      PS3  2013.0        Action
# 2            Grand Theft Auto: San Andreas      PS2  2004.0        Action
# 3                       Grand Theft Auto V     X360  2013.0        Action
# 4              Grand Theft Auto: Vice City      PS2  2002.0        Action
# 5                   Gran Turismo 3: A-Spec      PS2  2001.0        Racing
# 6           Call of Duty: Modern Warfare 3     X360  2011.0       Shooter
# 7                  Call of Duty: Black Ops     X360  2010.0       Shooter
# 8                Call of Duty: Black Ops 3      PS4  2015.0       Shooter
# 9               Call of Duty: Black Ops II      PS3  2012.0       Shooter
# 10              Call of Duty: Black Ops II     X360  2012.0       Shooter
# 11          Call of Duty: Modern Warfare 2     X360  2009.0       Shooter
# 12          Call of Duty: Modern Warfare 3      PS3  2011.0       Shooter
# 13                    Grand Theft Auto III      PS2  2001.0        Action
# 14                 Call of Duty: Black Ops      PS3  2010.0       Shooter
# 15                                  Halo 3     X360  2007.0       Shooter
# 16                      Grand Theft Auto V      PS4  2014.0        Action
# 17                          Gran Turismo 4      PS2  2004.0        Racing
# 18                     Grand Theft Auto IV     X360  2008.0        Action
# 19                            Gran Turismo       PS  1997.0        Racing
# 20                          Gran Turismo 5      PS3  2010.0        Racing
# 21          Call of Duty: Modern Warfare 2      PS3  2009.0       Shooter
# 22                     Grand Theft Auto IV      PS3  2008.0        Action
# 23                            Just Dance 3      Wii  2011.0          Misc
# 24                    Call of Duty: Ghosts     X360  2013.0       Shooter
# 25                             Halo: Reach     X360  2010.0       Shooter
# 26                                  Halo 4     X360  2012.0       Shooter
# 27                       Final Fantasy VII       PS  1997.0  Role-Playing
# 28                    Call of Duty: Ghosts      PS3  2013.0       Shooter
# 29                            Just Dance 2      Wii  2010.0          Misc
# 30                          Gran Turismo 2       PS  1999.0        Racing
# 41                        Atari      7280       450         0           80
# 42         Take-Two Interactive      2900      2830       240         1750
# 43              Electronic Arts      2930      3290       220         1230
# 44                   Activision      2800      3300       140         1370
# 45  Sony Computer Entertainment      3780      2170      1310          310
# 46                   Activision      4790      1900         0          690
# 47              Electronic Arts      4460      2130        60          690
# 48                   Activision      4520      2090        10          670
# 49                      Ubisoft      3510      3030         0          730
#
#     Total_Sales
# 0         21820
# 1         21390
# 2         20810
# 3         16380
# 4         16150
# 5         14970
# 6         14760
# 7         14640
# 8         14240
# 9         14040
# 10        13740
# 11        13520
# 12        13470
# 13        13100
# 14        12730
# 15        12140
# 16        11990
# 17        11650
# 18        11030
# 19        10949
# 20        10770
# 21        10690
# 22        10580
# 23        10270
# 24        10210
# 25         9870
# 26         9760
# 27         9720
# 28         9580
# 29         9520
# 30         9490
# 31         9320
# 32         9200
# 33         8840
# 34         8490
# 35         8480
# 36         8249
# 37         8110
# 38         8050
# 39         8040
# 40         7860
# 41         7810
# 42         7720
# 43         7670
# 44         7610
# 45         7570
# 46         7380
# 47         7340
# 48         7290
# 49         7270

# %%
plt.figure(figsize=(30,5))
plt.bar(np.arange(len(top_sales_x_nintendo.Name[:10]))-0.3, top_sales_x_nintendo.NA_Sales[:10], width=0.15, label='North America Sales')
plt.bar(np.arange(len(top_sales_x_nintendo.Name[:10]))-0.15, top_sales_x_nintendo.EU_Sales[:10], width=0.15, label='Europe Sales')
plt.bar(np.arange(len(top_sales_x_nintendo.Name[:10])), top_sales_x_nintendo.JP_Sales[:10], width=0.15, label='Japen Sales')
plt.bar(np.arange(len(top_sales_x_nintendo.Name[:10]))+0.15, top_sales_x_nintendo.Other_Sales[:10], width=0.15, label='ETC Sales')
plt.bar(np.arange(len(top_sales_x_nintendo.Name[:10]))+0.3, top_sales_x_nintendo.Total_Sales[:10], width=0.15, label='Total Sales')
plt.xticks(np.arange(len(top_sales_x_nintendo.Name[:10])),top_sales_x_nintendo.Name[:10])

plt.legend()
plt.xlabel('Game', fontsize=15)
plt.ylabel('# Sales[K]', fontsize=15)
plt.title('Top sold game except Nintendo', fontsize=18)
# Out:
# Text(0.5, 1.0, 'Top sold game except Nintendo')

# %% [markdown]
# # 5 결론

# %% [markdown]
# 1. 일본 시장을 제외하고는 시장은 게임 선호도가 유사하다
# 2. 연도별로 게임의 트렌드는 변화하며 최근인 2010 년대에 들어서는 액션, 슈팅, 스포츠, 롤플레잉 게임 장르의 판매량이 높다
# 3. 닌텐도에서 만든 게임의 판매량이 높으며 닌텐도 제작 게임을 제외하고는 GTA, Call of Duty 등 액션 슈팅 시리즈 게임들의 판매량이 높다
# 4. 출고 량이 높은 게임들은 북미 시장에서 판매량이 높다
#
# - 다음 게임은 북미시장을 타겟으로 하는 액션/슈팅 장르의 게임을 개발해야 하며, 시리즈로의 제작을 고려하고 기획해야한다.

# %% [markdown]
# -----

# %%
from matplotlib.font_manager

matplotlib.font_manager.findSystemFonts(fontpaths = None, fontext = 'ttf')
# Out:
#   Input In [151]
#     from matplotlib.font_manager
#                                 ^
# SyntaxError: invalid syntax
